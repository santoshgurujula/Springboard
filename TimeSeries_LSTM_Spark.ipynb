# %%
import mlflow
# Also autoinstruments tf.keras
import mlflow.tensorflow
mlflow.tensorflow.autolog()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/python/lib/python3.7/site-packages/tensorflow/python/pywrap_tensorflow_internal.py:15: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module&#39;s documentation for alternative uses
#   import imp
# </div>

# %%
# First, import the relevant modules
from matplotlib import pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
plt.rcParams['figure.figsize'] = 10,6
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import tensorflow as tf 
tf.test.gpu_device_name()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[3]: &#39;&#39;</div>

# %%
tf.__version__
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[4]: &#39;2.2.0&#39;</div>

# %%
# Verify that we're using TensorFlow 2.x
assert tf.__version__.startswith("2.")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#pointing the path to where data files are uploaded
display(dbutils.fs.ls("/FileStore/tables/ProjectData/"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/FileStore/tables/ProjectData/BOM500002.csv</td><td>BOM500002.csv</td><td>91432</td></tr><tr><td>dbfs:/FileStore/tables/ProjectData/BOM500003.csv</td><td>BOM500003.csv</td><td>86584</td></tr><tr><td>dbfs:/FileStore/tables/ProjectData/BOM500008.csv</td><td>BOM500008.csv</td><td>88389</td></tr><tr><td>dbfs:/FileStore/tables/ProjectData/BOM500009.csv</td><td>BOM500009.csv</td><td>81754</td></tr><tr><td>dbfs:/FileStore/tables/ProjectData/BOM500010.csv</td><td>BOM500010.csv</td><td>95670</td></tr><tr><td>dbfs:/FileStore/tables/ProjectData/BOM500012.csv</td><td>BOM500012.csv</td><td>82758</td></tr><tr><td>dbfs:/FileStore/tables/ProjectData/BOM500013.csv</td><td>BOM500013.csv</td><td>80411</td></tr><tr><td>dbfs:/FileStore/tables/ProjectData/BOM500014.csv</td><td>BOM500014.csv</td><td>73870</td></tr><tr><td>dbfs:/FileStore/tables/ProjectData/BOM500020.csv</td><td>BOM500020.csv</td><td>88039</td></tr><tr><td>dbfs:/FileStore/tables/ProjectData/BOM500023.csv</td><td>BOM500023.csv</td><td>65264</td></tr><tr><td>dbfs:/FileStore/tables/ProjectData/DJI.csv</td><td>DJI.csv</td><td>84079</td></tr><tr><td>dbfs:/FileStore/tables/ProjectData/FinalStockData.csv</td><td>FinalStockData.csv</td><td>799537</td></tr><tr><td>dbfs:/FileStore/tables/ProjectData/nasdl.csv</td><td>nasdl.csv</td><td>41735</td></tr></tbody></table></div>

# %%
# %fs ls /FileStore/tables/ProjectData/FinalStockData.csv
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/FileStore/tables/ProjectData/FinalStockData.csv</td><td>FinalStockData.csv</td><td>799537</td></tr></tbody></table></div>

# %%
# File location and type
file_location = "/FileStore/tables/ProjectData/FinalStockData.csv"
file_type = "csv"

# CSV options
infer_schema = "true"
first_row_is_header = "true"
delimiter = ","

# The applied options are for CSV files. For other file types, these will be ignored.
df = spark.read.format(file_type) \
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .load(file_location)

display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_c0</th><th>Date</th><th>Open_BOM500002</th><th>Open_BOM500003</th><th>Open_BOM500008</th><th>Open_BOM500009</th><th>Open_BOM500010</th><th>Open_BOM500012</th><th>Open_BOM500013</th><th>Open_BOM500014</th><th>Open_BOM500020</th><th>Open_BOM500023</th><th>High_BOM500002</th><th>High_BOM500003</th><th>High_BOM500008</th><th>High_BOM500009</th><th>High_BOM500010</th><th>High_BOM500012</th><th>High_BOM500013</th><th>High_BOM500014</th><th>High_BOM500020</th><th>High_BOM500023</th><th>Low_BOM500002</th><th>Low_BOM500003</th><th>Low_BOM500008</th><th>Low_BOM500009</th><th>Low_BOM500010</th><th>Low_BOM500012</th><th>Low_BOM500013</th><th>Low_BOM500014</th><th>Low_BOM500020</th><th>Low_BOM500023</th><th>Close_BOM500002</th><th>Close_BOM500003</th><th>Close_BOM500008</th><th>Close_BOM500009</th><th>Close_BOM500010</th><th>Close_BOM500012</th><th>Close_BOM500013</th><th>Close_BOM500014</th><th>Close_BOM500020</th><th>Close_BOM500023</th><th>WAP_BOM500002</th><th>WAP_BOM500003</th><th>WAP_BOM500008</th><th>WAP_BOM500009</th><th>WAP_BOM500010</th><th>WAP_BOM500012</th><th>WAP_BOM500013</th><th>WAP_BOM500014</th><th>WAP_BOM500020</th><th>WAP_BOM500023</th><th>No. of Shares_BOM500002</th><th>No. of Shares_BOM500003</th><th>No. of Shares_BOM500008</th><th>No. of Shares_BOM500009</th><th>No. of Shares_BOM500010</th><th>No. of Shares_BOM500012</th><th>No. of Shares_BOM500013</th><th>No. of Shares_BOM500014</th><th>No. of Shares_BOM500020</th><th>No. of Shares_BOM500023</th><th>No. of Trades_BOM500002</th><th>No. of Trades_BOM500003</th><th>No. of Trades_BOM500008</th><th>No. of Trades_BOM500009</th><th>No. of Trades_BOM500010</th><th>No. of Trades_BOM500012</th><th>No. of Trades_BOM500013</th><th>No. of Trades_BOM500014</th><th>No. of Trades_BOM500020</th><th>No. of Trades_BOM500023</th><th>Total Turnover_BOM500002</th><th>Total Turnover_BOM500003</th><th>Total Turnover_BOM500008</th><th>Total Turnover_BOM500009</th><th>Total Turnover_BOM500010</th><th>Total Turnover_BOM500012</th><th>Total Turnover_BOM500013</th><th>Total Turnover_BOM500014</th><th>Total Turnover_BOM500020</th><th>Total Turnover_BOM500023</th><th>Deliverable Quantity_BOM500002</th><th>Deliverable Quantity_BOM500003</th><th>Deliverable Quantity_BOM500008</th><th>Deliverable Quantity_BOM500009</th><th>Deliverable Quantity_BOM500010</th><th>Deliverable Quantity_BOM500012</th><th>Deliverable Quantity_BOM500013</th><th>Deliverable Quantity_BOM500014</th><th>Deliverable Quantity_BOM500020</th><th>Deliverable Quantity_BOM500023</th><th>% Deli. Qty to Traded Qty_BOM500002</th><th>% Deli. Qty to Traded Qty_BOM500003</th><th>% Deli. Qty to Traded Qty_BOM500008</th><th>% Deli. Qty to Traded Qty_BOM500009</th><th>% Deli. Qty to Traded Qty_BOM500010</th><th>% Deli. Qty to Traded Qty_BOM500012</th><th>% Deli. Qty to Traded Qty_BOM500013</th><th>% Deli. Qty to Traded Qty_BOM500014</th><th>% Deli. Qty to Traded Qty_BOM500020</th><th>% Deli. Qty to Traded Qty_BOM500023</th><th>Spread H-L_BOM500002</th><th>Spread H-L_BOM500003</th><th>Spread H-L_BOM500008</th><th>Spread H-L_BOM500009</th><th>Spread H-L_BOM500010</th><th>Spread H-L_BOM500012</th><th>Spread H-L_BOM500013</th><th>Spread H-L_BOM500014</th><th>Spread H-L_BOM500020</th><th>Spread H-L_BOM500023</th><th>Spread C-O_BOM500002</th><th>Spread C-O_BOM500003</th><th>Spread C-O_BOM500008</th><th>Spread C-O_BOM500009</th><th>Spread C-O_BOM500010</th><th>Spread C-O_BOM500012</th><th>Spread C-O_BOM500013</th><th>Spread C-O_BOM500014</th><th>Spread C-O_BOM500020</th><th>Spread C-O_BOM500023</th><th>Gross_Purchases</th><th>Gross_Sales</th><th>Net_Investment_INR</th><th>Net_Investment_USD</th><th>Conversion_Rate</th><th>High</th><th>Low</th><th>Open</th><th>Close</th><th>Volume</th><th>Adj Close</th></tr></thead><tbody><tr><td>0</td><td>2017-01-02</td><td>1045.0</td><td>129.0</td><td>870.05</td><td>7.0</td><td>1275.0</td><td>21.9< ...

# %%
dataset = df.select("*").toPandas()
dataset.info()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;class &#39;pandas.core.frame.DataFrame&#39;&gt;
# RangeIndex: 862 entries, 0 to 861
# Columns: 133 entries, _c0 to Adj Close
# dtypes: float64(131), int32(1), object(1)
# memory usage: 892.4+ KB
# </div>

# %%
dataset.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>_c0</th>
#       <th>Date</th>
#       <th>Open_BOM500002</th>
#       <th>Open_BOM500003</th>
#       <th>Open_BOM500008</th>
#       <th>Open_BOM500009</th>
#       <th>Open_BOM500010</th>
#       <th>Open_BOM500012</th>
#       <th>Open_BOM500013</th>
#       <th>Open_BOM500014</th>
#       <th>Open_BOM500020</th>
#       <th>Open_BOM500023</th>
#       <th>High_BOM500002</th>
#       <th>High_BOM500003</th>
#       <th>High_BOM500008</th>
#       <th>High_BOM500009</th>
#       <th>High_BOM500010</th>
#       <th>High_BOM500012</th>
#       <th>High_BOM500013</th>
#       <th>High_BOM500014</th>
#       <th>High_BOM500020</th>
#       <th>High_BOM500023</th>
#       <th>Low_BOM500002</th>
#       <th>Low_BOM500003</th>
#       <th>Low_BOM500008</th>
#       <th>Low_BOM500009</th>
#       <th>Low_BOM500010</th>
#       <th>Low_BOM500012</th>
#       <th>Low_BOM500013</th>
#       <th>Low_BOM500014</th>
#       <th>Low_BOM500020</th>
#       <th>Low_BOM500023</th>
#       <th>Close_BOM500002</th>
#       <th>Close_BOM500003</th>
#       <th>Close_BOM500008</th>
#       <th>Close_BOM500009</th>
#       <th>Close_BOM500010</th>
#       <th>Close_BOM500012</th>
#       <th>Close_BOM500013</th>
#       <th>Close_BOM500014</th>
#       <th>...</th>
#       <th>% Deli. Qty to Traded Qty_BOM500003</th>
#       <th>% Deli. Qty to Traded Qty_BOM500008</th>
#       <th>% Deli. Qty to Traded Qty_BOM500009</th>
#       <th>% Deli. Qty to Traded Qty_BOM500010</th>
#       <th>% Deli. Qty to Traded Qty_BOM500012</th>
#       <th>% Deli. Qty to Traded Qty_BOM500013</th>
#       <th>% Deli. Qty to Traded Qty_BOM500014</th>
#       <th>% Deli. Qty to Traded Qty_BOM500020</th>
#       <th>% Deli. Qty to Traded Qty_BOM500023</th>
#       <th>Spread H-L_BOM500002</th>
#       <th>Spread H-L_BOM500003</th>
#       <th>Spread H-L_BOM500008</th>
#       <th>Spread H-L_BOM500009</th>
#       <th>Spread H-L_BOM500010</th>
#       <th>Spread H-L_BOM500012</th>
#       <th>Spread H-L_BOM500013</th>
#       <th>Spread H-L_BOM500014</th>
#       <th>Spread H-L_BOM500020</th>
#       <th>Spread H-L_BOM500023</th>
#       <th>Spread C-O_BOM500002</th>
#       <th>Spread C-O_BOM500003</th>
#       <th>Spread C-O_BOM500008</th>
#       <th>Spread C-O_BOM500009</th>
#       <th>Spread C-O_BOM500010</th>
#       <th>Spread C-O_BOM500012</th>
#       <th>Spread C-O_BOM500013</th>
#       <th>Spread C-O_BOM500014</th>
#       <th>Spread C-O_BOM500020</th>
#       <th>Spread C-O_BOM500023</th>
#       <th>Gross_Purchases</th>
#       <th>Gross_Sales</th>
#       <th>Net_Investment_INR</th>
#       <th>Net_Investment_USD</th>
#       <th>Conversion_Rate</th>
#       <th>High</th>
#       <th>Low</th>
#       <th>Open</th>
#       <th>Close</th>
#       <th>Volume</th>
#       <th>Adj Close</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td
td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2017-01-04</td>
#       <td>1050.0</td>
#       <td>1037.35</td>
#       <td>68.0864</td>
#       <td>19890.939453</td>
#       <td>19942.160156</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2017-01-05</td>
#       <td>1051.9</td>
#       <td>1031.45</td>
#       <td>68.1791</td>
#       <td>19924.560547</td>
#       <td>19899.289062</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2017-01-06</td>
#       <td>1037.0</td>
#       <td>1043.90</td>
#       <td>67.7884</td>
#       <td>19906.960938</td>
#       <td>19963.800781</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
sub_dataset.sort_values(by='Date')
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Date</th>
#       <th>Open_BOM500002</th>
#       <th>Close_BOM500002</th>
#       <th>Conversion_Rate</th>
#       <th>DJIOpen</th>
#       <th>DJIClose</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2017-01-02</td>
#       <td>1045.00</td>
#       <td>1039.95</td>
#       <td>67.9547</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2017-01-03</td>
#       <td>1069.90</td>
#       <td>1045.05</td>
#       <td>68.0225</td>
#       <td>19872.859375</td>
#       <td>19881.759766</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2017-01-04</td>
#       <td>1050.00</td>
#       <td>1037.35</td>
#       <td>68.0864</td>
#       <td>19890.939453</td>
#       <td>19942.160156</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2017-01-05</td>
#       <td>1051.90</td>
#       <td>1031.45</td>
#       <td>68.1791</td>
#       <td>19924.560547</td>
#       <td>19899.289062</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2017-01-06</td>
#       <td>1037.00</td>
#       <td>1043.90</td>
#       <td>67.7884</td>
#       <td>19906.960938</td>
#       <td>19963.800781</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>857</th>
#       <td>2020-06-24</td>
#       <td>854.65</td>
#       <td>866.50</td>
#       <td>75.7549</td>
#       <td>25992.960938</td>
#       <td>25445.939453</td>
#     </tr>
#     <tr>
#       <th>858</th>
#       <td>2020-06-25</td>
#       <td>870.00</td>
#       <td>887.50</td>
#       <td>75.7087</td>
#       <td>25365.220703</td>
#       <td>25745.599609</td>
#     </tr>
#     <tr>
#       <th>859</th>
#       <td>2020-06-26</td>
#       <td>888.00</td>
#       <td>913.60</td>
#       <td>75.6349</td>
#       <td>25641.689453</td>
#       <td>25015.550781</td>
#     </tr>
#     <tr>
#       <th>860</th>
#       <td>2020-06-29</td>
#       <td>915.00</td>
#       <td>919.90</td>
#       <td>75.4757</td>
#       <td>25152.449219</td>
#       <td>25595.800781</td>
#     </tr>
#     <tr>
#       <th>861</th>
#       <td>2020-06-30</td>
#       <td>925.00</td>
#       <td>943.60</td>
#       <td>75.5680</td>
#       <td>25512.429688</td>
#       <td>25812.880859</td>
#     </tr>
#   </tbody>
# </table>
# <p>862 rows × 6 columns</p>
# </div>

# %%
#parse string to datetime
sub_dataset['Date']=pd.to_datetime(sub_dataset['Date'],infer_datetime_format=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Set date as Index
sub_dataset.set_index('Date',inplace=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
sub_dataset.info()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;class &#39;pandas.core.frame.DataFrame&#39;&gt;
# DatetimeIndex: 862 entries, 2017-01-02 to 2020-06-30
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Open_BOM500002   862 non-null    float64
#  1   Close_BOM500002  862 non-null    float64
#  2   Conversion_Rate  862 non-null    float64
#  3   DJIOpen          861 non-null    float64
#  4   DJIClose         861 non-null    float64
# dtypes: float64(5)
# memory usage: 40.4 KB
# </div>

# %%
sub_dataset[sub_dataset['Close_BOM500002'].isna()]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Open_BOM500002</th>
#       <th>Close_BOM500002</th>
#       <th>Conversion_Rate</th>
#       <th>DJIOpen</th>
#       <th>DJIClose</th>
#     </tr>
#     <tr>
#       <th>Date</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>
# </div>

# %%
from pandas import DataFrame
from pandas import concat
 
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
	"""
	Frame a time series as a supervised learning dataset.
	Arguments:
		data: Sequence of observations as a list or NumPy array.
		n_in: Number of lag observations as input (X).
		n_out: Number of observations as output (y).
		dropnan: Boolean whether or not to drop rows with NaN values.
	Returns:
		Pandas DataFrame of series framed for supervised learning.
	"""
	n_vars = 1 if type(data) is list else data.shape[1]
	v_cols = 'Var' if type(data) is list else data.columns
	df = DataFrame(data)
	cols, names = list(), list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(df.shift(i))
		names += [(v_cols[j]+'%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(df.shift(-i))
		if i == 0:
			names += [(v_cols[j]+'%d(t)' % (j+1)) for j in range(n_vars)]
		else:
			names += [(v_cols[j]+'%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
	# put it all together
	agg = concat(cols, axis=1)
	agg.columns = names
	# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
n_timesteps=5
n_features=len(sub_dataset.columns)
data = series_to_supervised(sub_dataset,n_timesteps,1,True)
data.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Open_BOM5000021(t-5)</th>
#       <th>Close_BOM5000022(t-5)</th>
#       <th>Conversion_Rate3(t-5)</th>
#       <th>DJIOpen4(t-5)</th>
#       <th>DJIClose5(t-5)</th>
#       <th>Open_BOM5000021(t-4)</th>
#       <th>Close_BOM5000022(t-4)</th>
#       <th>Conversion_Rate3(t-4)</th>
#       <th>DJIOpen4(t-4)</th>
#       <th>DJIClose5(t-4)</th>
#       <th>Open_BOM5000021(t-3)</th>
#       <th>Close_BOM5000022(t-3)</th>
#       <th>Conversion_Rate3(t-3)</th>
#       <th>DJIOpen4(t-3)</th>
#       <th>DJIClose5(t-3)</th>
#       <th>Open_BOM5000021(t-2)</th>
#       <th>Close_BOM5000022(t-2)</th>
#       <th>Conversion_Rate3(t-2)</th>
#       <th>DJIOpen4(t-2)</th>
#       <th>DJIClose5(t-2)</th>
#       <th>Open_BOM5000021(t-1)</th>
#       <th>Close_BOM5000022(t-1)</th>
#       <th>Conversion_Rate3(t-1)</th>
#       <th>DJIOpen4(t-1)</th>
#       <th>DJIClose5(t-1)</th>
#       <th>Open_BOM5000021(t)</th>
#       <th>Close_BOM5000022(t)</th>
#       <th>Conversion_Rate3(t)</th>
#       <th>DJIOpen4(t)</th>
#       <th>DJIClose5(t)</th>
#     </tr>
#     <tr>
#       <th>Date</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2017-01-10</th>
#       <td>1069.90</td>
#       <td>1045.05</td>
#       <td>68.0225</td>
#       <td>19872.859375</td>
#       <td>19881.759766</td>
#       <td>1050.00</td>
#       <td>1037.35</td>
#       <td>68.0864</td>
#       <td>19890.939453</td>
#       <td>19942.160156</td>
#       <td>1051.90</td>
#       <td>1031.45</td>
#       <td>68.1791</td>
#       <td>19924.560547</td>
#       <td>19899.289062</td>
#       <td>1037.00</td>
#       <td>1043.90</td>
#       <td>67.7884</td>
#       <td>19906.960938</td>
#       <td>19963.800781</td>
#       <td>1047.95</td>
#       <td>1041.95</td>
#       <td>67.9522</td>
#       <td>19931.410156</td>
#       <td>19887.380859</td>
#       <td>1045.00</td>
#       <td>1176.00</td>
#       <td>68.1863</td>
#       <td>19876.349609</td>
#       <td>19855.529297</td>
#     </tr>
#     <tr>
#       <th>2017-01-11</th>
#       <td>1050.00</td>
#       <td>1037.35</td>
#       <td>68.0864</td>
#       <td>19890.939453</td>
#       <td>19942.160156</td>
#       <td>1051.90</td>
#       <td>1031.45</td>
#       <td>68.1791</td>
#       <td>19924.560547</td>
#       <td>19899.289062</td>
#       <td>1037.00</td>
#       <td>1043.90</td>
#       <td>67.7884</td>
#       <td>19906.960938</td>
#       <td>19963.800781</td>
#       <td>1047.95</td>
#       <td>1041.95</td>
#       <td>67.9522</td>
#       <td>19931.410156</td>
#       <td>19887.380859</td>
#       <td>1045.00</td>
#       <td>1176.00</td>
#       <td>68.1863</td>
#       <td>19876.349609</td>
#       <td>19855.529297</td>
#       <td>1166.90</td>
#       <td>1132.15</td>
#       <td>68.0641</td>
#       <td>19887.380859</td>
#       <td>19954.279297</td>
#     </tr>
#     <tr>
#       <th>2017-01-12</th>
#       <td>1051.90</td>
#       <td>1031.45</td>
#       <td>68.1791</td>
#       <td>19924.560547</td>
#       <td>19899.289062</td>
#       <td>1037.00</td>
#       <td>1043.90</td>
#       <td>67.7884</td>
#       <td>19906.960938</td>
#       <td>19963.800781</td>
#       <td>1047.95</td>
#       <td>1041.95</td>
#       <td>67.9522</td>
#       <td>19931.410156</td>
#       <td>19887.380859</td>
#       <td>1045.00</td>
#       <td>1176.00</td>
#       <td>68.1863</td>
#       <td>19876.349609</td>
#       <td>19855.529297</td>
#       <td>1166.90</td>
#       <td>1132.15</td>
#       <td>68.0641</td>
#       <td>19887.380859</td>
#       <td>19954.279297</td>
#       <td>1139.75</td>
#       <td>1122.10</td>
#       <td>68.2276</td>
#       <td>19926.210938</td>
#       <td>19891.000000</td>
#     </tr>
#     <tr>
#       <th>2017-01-13</th>
#       <td>1037.00</td>
#       <td>1043.90</td>
#       <td>67.7884</td>
#       <td>19906.960938</td>
#       <td>19963.800781</td>
#       <td>1047.95</td>
#       <td>1041.95</td>
#       <td>67.9522</td>
#       <td>19931.410156</td>
#       <td>19887.380859</td>
#       <td>1045.00</td>
#       <td>1176.00</td>
#       <td>68.1863</td>
#       <td>19876.349609</td>
#       <td>19855.529297</td>
#       <td>1166.90</td>
#       <td>1132.15</td>
#       <td>68.0641</td>
#       <td>19887.380859</td>
#       <td>19954.279297</td>
#       <td>1139.75</td>
#       <td>1122.10</td>
#       <td>68.2276</td>
#       <td>19926.210938</td>
#       <td>19891.000000</td>
#       <td>1130.00</td>
#       <td>1130.85</td>
#       <td>68.0858</td>
#       <td>19912.539062</td>
#       <td>19885.730469</td>
#     </tr>
#     <tr>
#       <th>2017-01-16</th>
#       <td>1047.95</td>
#       <td>1041.95</td>
#       <td>67.9522</td>
#       <td>19931.410156</td>
#       <td>19887.380859</td>
#       <td>1045.00</td>
#       <td>1176.00</td>
#       <td>68.1863</td>
#       <td>19876.349609</td>
#       <td>19855.529297</td>
#       <td>1166.90</td>
#       <td>1132.15</td>
#       <td>68.0641</td>
#       <td>19887.380859</td>
#       <td>19954.279297</td>
#       <td>1139.75</td>
#       <td>1122.10</td>
#       <td>68.2276</td>
#       <td>19926.210938</td>
#       <td>19891.000000</td>
#       <td>1130.00</td>
#       <td>1130.85</td>
#       <td>68.0858</td>
#       <td>19912.539062</td>
#       <td>19885.730469</td>
#       <td>1125.00</td>
#       <td>1124.45</td>
#       <td>68.2310</td>
#       <td>19880.679688</td>
#       <td>19856.250000</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
#Stock code we want to predict
target_stock='Close_BOM5000022'
columns=data.columns

#Keep on Target_stock(t) and drop other variables of (t), as we want to predict only target_stock(t)
reframed_data=data.drop([i for i in columns if '(t)' in i and i!= target_stock+'(t)'],axis=1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
reframed_data.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Open_BOM5000021(t-5)</th>
#       <th>Close_BOM5000022(t-5)</th>
#       <th>Conversion_Rate3(t-5)</th>
#       <th>DJIOpen4(t-5)</th>
#       <th>DJIClose5(t-5)</th>
#       <th>Open_BOM5000021(t-4)</th>
#       <th>Close_BOM5000022(t-4)</th>
#       <th>Conversion_Rate3(t-4)</th>
#       <th>DJIOpen4(t-4)</th>
#       <th>DJIClose5(t-4)</th>
#       <th>Open_BOM5000021(t-3)</th>
#       <th>Close_BOM5000022(t-3)</th>
#       <th>Conversion_Rate3(t-3)</th>
#       <th>DJIOpen4(t-3)</th>
#       <th>DJIClose5(t-3)</th>
#       <th>Open_BOM5000021(t-2)</th>
#       <th>Close_BOM5000022(t-2)</th>
#       <th>Conversion_Rate3(t-2)</th>
#       <th>DJIOpen4(t-2)</th>
#       <th>DJIClose5(t-2)</th>
#       <th>Open_BOM5000021(t-1)</th>
#       <th>Close_BOM5000022(t-1)</th>
#       <th>Conversion_Rate3(t-1)</th>
#       <th>DJIOpen4(t-1)</th>
#       <th>DJIClose5(t-1)</th>
#       <th>Close_BOM5000022(t)</th>
#     </tr>
#     <tr>
#       <th>Date</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2017-01-10</th>
#       <td>1069.90</td>
#       <td>1045.05</td>
#       <td>68.0225</td>
#       <td>19872.859375</td>
#       <td>19881.759766</td>
#       <td>1050.00</td>
#       <td>1037.35</td>
#       <td>68.0864</td>
#       <td>19890.939453</td>
#       <td>19942.160156</td>
#       <td>1051.90</td>
#       <td>1031.45</td>
#       <td>68.1791</td>
#       <td>19924.560547</td>
#       <td>19899.289062</td>
#       <td>1037.00</td>
#       <td>1043.90</td>
#       <td>67.7884</td>
#       <td>19906.960938</td>
#       <td>19963.800781</td>
#       <td>1047.95</td>
#       <td>1041.95</td>
#       <td>67.9522</td>
#       <td>19931.410156</td>
#       <td>19887.380859</td>
#       <td>1176.00</td>
#     </tr>
#     <tr>
#       <th>2017-01-11</th>
#       <td>1050.00</td>
#       <td>1037.35</td>
#       <td>68.0864</td>
#       <td>19890.939453</td>
#       <td>19942.160156</td>
#       <td>1051.90</td>
#       <td>1031.45</td>
#       <td>68.1791</td>
#       <td>19924.560547</td>
#       <td>19899.289062</td>
#       <td>1037.00</td>
#       <td>1043.90</td>
#       <td>67.7884</td>
#       <td>19906.960938</td>
#       <td>19963.800781</td>
#       <td>1047.95</td>
#       <td>1041.95</td>
#       <td>67.9522</td>
#       <td>19931.410156</td>
#       <td>19887.380859</td>
#       <td>1045.00</td>
#       <td>1176.00</td>
#       <td>68.1863</td>
#       <td>19876.349609</td>
#       <td>19855.529297</td>
#       <td>1132.15</td>
#     </tr>
#     <tr>
#       <th>2017-01-12</th>
#       <td>1051.90</td>
#       <td>1031.45</td>
#       <td>68.1791</td>
#       <td>19924.560547</td>
#       <td>19899.289062</td>
#       <td>1037.00</td>
#       <td>1043.90</td>
#       <td>67.7884</td>
#       <td>19906.960938</td>
#       <td>19963.800781</td>
#       <td>1047.95</td>
#       <td>1041.95</td>
#       <td>67.9522</td>
#       <td>19931.410156</td>
#       <td>19887.380859</td>
#       <td>1045.00</td>
#       <td>1176.00</td>
#       <td>68.1863</td>
#       <td>19876.349609</td>
#       <td>19855.529297</td>
#       <td>1166.90</td>
#       <td>1132.15</td>
#       <td>68.0641</td>
#       <td>19887.380859</td>
#       <td>19954.279297</td>
#       <td>1122.10</td>
#     </tr>
#     <tr>
#       <th>2017-01-13</th>
#       <td>1037.00</td>
#       <td>1043.90</td>
#       <td>67.7884</td>
#       <td>19906.960938</td>
#       <td>19963.800781</td>
#       <td>1047.95</td>
#       <td>1041.95</td>
#       <td>67.9522</td>
#       <td>19931.410156</td>
#       <td>19887.380859</td>
#       <td>1045.00</td>
#       <td>1176.00</td>
#       <td>68.1863</td>
#       <td>19876.349609</td>
#       <td>19855.529297</td>
#       <td>1166.90</td>
#       <td>1132.15</td>
#       <td>68.0641</td>
#       <td>19887.380859</td>
#       <td>19954.279297</td>
#       <td>1139.75</td>
#       <td>1122.10</td>
#       <td>68.2276</td>
#       <td>19926.210938</td>
#       <td>19891.000000</td>
#       <td>1130.85</td>
#     </tr>
#     <tr>
#       <th>2017-01-16</th>
#       <td>1047.95</td>
#       <td>1041.95</td>
#       <td>67.9522</td>
#       <td>19931.410156</td>
#       <td>19887.380859</td>
#       <td>1045.00</td>
#       <td>1176.00</td>
#       <td>68.1863</td>
#       <td>19876.349609</td>
#       <td>19855.529297</td>
#       <td>1166.90</td>
#       <td>1132.15</td>
#       <td>68.0641</td>
#       <td>19887.380859</td>
#       <td>19954.279297</td>
#       <td>1139.75</td>
#       <td>1122.10</td>
#       <td>68.2276</td>
#       <td>19926.210938</td>
#       <td>19891.000000</td>
#       <td>1130.00</td>
#       <td>1130.85</td>
#       <td>68.0858</td>
#       <td>19912.539062</td>
#       <td>19885.730469</td>
#       <td>1124.45</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
#split scaled df to train and test data
train_data, test_data = reframed_data.iloc[0:int(len(reframed_data)*0.8), :], reframed_data.iloc[int(len(reframed_data)*0.8):, :]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
train_data_scaled = scaler.fit_transform(train_data.values)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#transform test data
test_data_scaled= scaler.transform(test_data)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#convert train scaled array to DF
train_scaled_df=pd.DataFrame(train_data_scaled,index=train_data.index,columns=train_data.columns)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#convert test scaled array to DF
test_scaled_df=pd.DataFrame(test_data_scaled,index=test_data.index,columns=test_data.columns)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
train_scaled_df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Open_BOM5000021(t-5)</th>
#       <th>Close_BOM5000022(t-5)</th>
#       <th>Conversion_Rate3(t-5)</th>
#       <th>DJIOpen4(t-5)</th>
#       <th>DJIClose5(t-5)</th>
#       <th>Open_BOM5000021(t-4)</th>
#       <th>Close_BOM5000022(t-4)</th>
#       <th>Conversion_Rate3(t-4)</th>
#       <th>DJIOpen4(t-4)</th>
#       <th>DJIClose5(t-4)</th>
#       <th>Open_BOM5000021(t-3)</th>
#       <th>Close_BOM5000022(t-3)</th>
#       <th>Conversion_Rate3(t-3)</th>
#       <th>DJIOpen4(t-3)</th>
#       <th>DJIClose5(t-3)</th>
#       <th>Open_BOM5000021(t-2)</th>
#       <th>Close_BOM5000022(t-2)</th>
#       <th>Conversion_Rate3(t-2)</th>
#       <th>DJIOpen4(t-2)</th>
#       <th>DJIClose5(t-2)</th>
#       <th>Open_BOM5000021(t-1)</th>
#       <th>Close_BOM5000022(t-1)</th>
#       <th>Conversion_Rate3(t-1)</th>
#       <th>DJIOpen4(t-1)</th>
#       <th>DJIClose5(t-1)</th>
#       <th>Close_BOM5000022(t)</th>
#     </tr>
#     <tr>
#       <th>Date</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2017
#       <td>0.012327</td>
#       <td>0.215489</td>
#       <td>0.438261</td>
#       <td>0.010789</td>
#       <td>0.016144</td>
#       <td>0.200154</td>
#       <td>0.150119</td>
#       <td>0.427192</td>
#       <td>0.012246</td>
#       <td>0.029092</td>
#       <td>0.158320</td>
#       <td>0.121384</td>
#       <td>0.442003</td>
#       <td>0.017375</td>
#       <td>0.020795</td>
#       <td>0.132605</td>
#       <td>0.134636</td>
#       <td>0.429158</td>
#       <td>0.015569</td>
#       <td>0.020104</td>
#       <td>0.049749</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
train_scaled_df.shape
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[28]: (684, 26)</div>

# %%
test_scaled_df.shape
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[29]: (172, 26)</div>

# %%
# split into input and outputs
train_X, train_y = train_scaled_df[:].drop(target_stock+'(t)',axis=1,inplace=False).values, train_scaled_df[target_stock+'(t)'].values
test_X, test_y = test_scaled_df[:].drop(target_stock+'(t)',axis=1,inplace=False).values, test_scaled_df[target_stock+'(t)'].values
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
train_X.shape,train_y.shape
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[31]: ((684, 25), (684,))</div>

# %%
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], n_timesteps, n_features))
test_X = test_X.reshape((test_X.shape[0], n_timesteps, n_features))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">(684, 5, 5) (684,) (172, 5, 5) (172,)
# </div>

# %%
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# design network
model = Sequential()
model.add(LSTM(50, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')

model.summary()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/python/lib/python3.7/site-packages/tensorflow/python/keras/layers/recurrent.py:820: DeprecationWarning: Using or importing the ABCs from &#39;collections&#39; instead of from &#39;collections.abc&#39; is deprecated since Python 3.3,and in 3.9 it will stop working
#   if (isinstance(inputs, collections.Sequence)
# Model: &#34;sequential&#34;
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 50)                11200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 51
# =================================================================
# Total params: 11,251
# Trainable params: 11,251
# Non-trainable params: 0
# _________________________________________________________________
# </div>

# %%
# fit network
history = model.fit(train_X, train_y, epochs=50, batch_size=72, validation_data=(test_X, test_y), verbose=2, shuffle=False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Epoch 1/50
# 10/10 - 1s - loss: 0.2227 - val_loss: 0.3922
# Epoch 2/50
# 10/10 - 0s - loss: 0.1757 - val_loss: 0.3980
# Epoch 3/50
# 10/10 - 0s - loss: 0.1210 - val_loss: 0.2808
# Epoch 4/50
# 10/10 - 0s - loss: 0.1019 - val_loss: 0.2223
# Epoch 5/50
# 10/10 - 0s - loss: 0.0789 - val_loss: 0.1665
# Epoch 6/50
# 10/10 - 0s - loss: 0.0691 - val_loss: 0.1393
# Epoch 7/50
# 10/10 - 0s - loss: 0.0681 - val_loss: 0.1435
# Epoch 8/50
# 10/10 - 0s - loss: 0.0617 - val_loss: 0.1430
# Epoch 9/50
# 10/10 - 0s - loss: 0.0613 - val_loss: 0.1411
# Epoch 10/50
# 10/10 - 0s - loss: 0.0566 - val_loss: 0.1328
# Epoch 11/50
# 10/10 - 0s - loss: 0.0567 - val_loss: 0.1315
# Epoch 12/50
# 10/10 - 0s - loss: 0.0534 - val_loss: 0.1252
# Epoch 13/50
# 10/10 - 0s - loss: 0.0531 - val_loss: 0.1216
# Epoch 14/50
# 10/10 - 0s - loss: 0.0517 - val_loss: 0.1196
# Epoch 15/50
# 10/10 - 0s - loss: 0.0513 - val_loss: 0.1176
# Epoch 16/50
# 10/10 - 0s - loss: 0.0505 - val_loss: 0.1149
# Epoch 17/50
# 10/10 - 0s - loss: 0.0501 - val_loss: 0.1111
# Epoch 18/50
# 10/10 - 0s - loss: 0.0496 - val_loss: 0.1081
# Epoch 19/50
# 10/10 - 0s - loss: 0.0493 - val_loss: 0.1069
# Epoch 20/50
# 10/10 - 0s - loss: 0.0493 - val_loss: 0.1033
# Epoch 21/50
# 10/10 - 0s - loss: 0.0486 - val_loss: 0.1004
# Epoch 22/50
# 10/10 - 0s - loss: 0.0485 - val_loss: 0.1038
# Epoch 23/50
# 10/10 - 0s - loss: 0.0498 - val_loss: 0.1030
# Epoch 24/50
# 10/10 - 0s - loss: 0.0494 - val_loss: 0.0911
# Epoch 25/50
# 10/10 - 0s - loss: 0.0484 - val_loss: 0.0981
# Epoch 26/50
# 10/10 - 0s - loss: 0.0508 - val_loss: 0.1108
# Epoch 27/50
# 10/10 - 0s - loss: 0.0556 - val_loss: 0.1005
# Epoch 28/50
# 10/10 - 0s - loss: 0.0504 - val_loss: 0.0904
# Epoch 29/50
# 10/10 - 0s - loss: 0.0546 - val_loss: 0.1059
# Epoch 30/50
# 10/10 - 0s - loss: 0.0547 - val_loss: 0.1134
# Epoch 31/50
# 10/10 - 0s - loss: 0.0514 - val_loss: 0.0937
# Epoch 32/50
# 10/10 - 0s - loss: 0.0485 - val_loss: 0.0934
# Epoch 33/50
# 10/10 - 0s - loss: 0.0485 - val_loss: 0.1003
# Epoch 34/50
# 10/10 - 0s - loss: 0.0482 - val_loss: 0.0881
# Epoch 35/50
# 10/10 - 0s - loss: 0.0459 - val_loss: 0.0871
# Epoch 36/50
# 10/10 - 0s - loss: 0.0478 - val_loss: 0.0958
# Epoch 37/50
# 10/10 - 0s - loss: 0.0489 - val_loss: 0.0895
# Epoch 38/50
# 10/10 - 0s - loss: 0.0455 - val_loss: 0.0817
# Epoch 39/50
# 10/10 - 0s - loss: 0.0477 - val_loss: 0.0899
# Epoch 40/50
# 10/10 - 0s - loss: 0.0477 - val_loss: 0.0924
# Epoch 41/50
# 10/10 - 0s - loss: 0.0463 - val_loss: 0.0781
# Epoch 42/50
# 10/10 - 0s - loss: 0.0450 - val_loss: 0.0816
# Epoch 43/50
# 10/10 - 0s - loss: 0.0472 - val_loss: 0.0911
# Epoch 44/50
# 10/10 - 0s - loss: 0.0492 - val_loss: 0.0822
# Epoch 45/50
# 10/10 - 0s - loss: 0.0454 - val_loss: 0.0761
# Epoch 46/50
# 10/10 - 0s - loss: 0.0487 - val_loss: 0.0861
# Epoch 47/50
# 10/10 - 0s - loss: 0.0482 - val_loss: 0.0894
# Epoch 48/50
# 10/10 - 0s - loss: 0.0455 - val_loss: 0.0731
# Epoch 49/50
# 10/10 - 0s - loss: 0.0447 - val_loss: 0.0754
# Epoch 50/50
# 10/10 - 0s - loss: 0.0454 - val_loss: 0.0817
# </div>

# %%
# plot history
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
# make a prediction
yhat = model.predict(test_X)
print(yhat.shape)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">(172, 1)
# </div>

# %%
test_X.shape
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[37]: (172, 5, 5)</div>

# %%
#Reshape test_x to origianl shape
test_X = test_X.reshape((test_X.shape[0], n_timesteps* n_features))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from numpy import concatenate
from math import sqrt

# invert scaling for forecast
inv_yhat = concatenate((yhat, test_X[:, :]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = concatenate((test_y, test_X[:, :]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]
# calculate RMSE
rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test RMSE: %.3f' % rmse)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Test RMSE: 68.896
# </div>

# %%
plt.plot(inv_y,label='Testing Data')
plt.plot(inv_yhat,label='Predicted price for Test data')
plt.legend();
