# %% [markdown]
# <a href="https://colab.research.google.com/github/santoshgurujula/Springboard/blob/master/TimeSeries_LSTM_V1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# First, import the relevant modules
from matplotlib import pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
plt.rcParams['figure.figsize'] = 10,6

# %%
import tensorflow as tf 
tf.test.gpu_device_name()
# Out:
# ''

# %%
tf.__version__
# Out:
# '2.3.0'

# %%
#pointing the path to google drive folder
# %cd '/content/drive/My Drive/Springboard/data'
# !ls
# Out:
# /content/drive/My Drive/Springboard/data
# BOM500002.csv  BOM500013.csv  fig2.png
# BOM500003.csv  BOM500014.csv  FinalStockData.csv
# BOM500008.csv  BOM500020.csv  interpolating-timeseries-p1-pandas-fig1.png
# BOM500009.csv  BOM500023.csv  nasdl.csv
# BOM500010.csv  DJI.csv
# BOM500012.csv  fig1.png

# %%
dataset = pd.read_csv('/content/drive/My Drive/Springboard/data/FinalStockData.csv')
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 862 entries, 0 to 861
# Columns: 133 entries, Unnamed: 0 to Adj Close
# dtypes: float64(131), int64(1), object(1)
# memory usage: 895.8+ KB

# %%
dataset.head()
# Out:
#    Unnamed: 0        Date  ...       Volume     Adj Close
# 0           0  2017-01-02  ...          NaN           NaN
# 1           1  2017-01-03  ...  339180000.0  19881.759766
# 2           2  2017-01-04  ...  280010000.0  19942.160156
# 3           3  2017-01-05  ...  269920000.0  19899.289062
# 4           4  2017-01-06  ...  277700000.0  19963.800781
#
# [5 rows x 133 columns]

# %%
#select only 1 stock Open and close, Conversion_rate , Dowjones Open and close columns
features= ['Date','Open_BOM500002','Close_BOM500002', 'Conversion_Rate','Open','Close']
sub_dataset=dataset[features]

# %%
#Rename DJI Open and CLose
sub_dataset=sub_dataset.rename(columns={"Open": "DJIOpen", "Close": "DJIClose"})

# %%
sub_dataset.head()
# Out:
#          Date  Open_BOM500002  ...       DJIOpen      DJIClose
# 0  2017-01-02          1045.0  ...           NaN           NaN
# 1  2017-01-03          1069.9  ...  19872.859375  19881.759766
# 2  2017-01-04          1050.0  ...  19890.939453  19942.160156
# 3  2017-01-05          1051.9  ...  19924.560547  19899.289062
# 4  2017-01-06          1037.0  ...  19906.960938  19963.800781
#
# [5 rows x 6 columns]

# %%
sub_dataset.sort_values(by='Date')
# Out:
#            Date  Open_BOM500002  ...       DJIOpen      DJIClose
# 0    2017-01-02         1045.00  ...           NaN           NaN
# 1    2017-01-03         1069.90  ...  19872.859375  19881.759766
# 2    2017-01-04         1050.00  ...  19890.939453  19942.160156
# 3    2017-01-05         1051.90  ...  19924.560547  19899.289062
# 4    2017-01-06         1037.00  ...  19906.960938  19963.800781
# ..          ...             ...  ...           ...           ...
# 857  2020-06-24          854.65  ...  25992.960938  25445.939453
# 858  2020-06-25          870.00  ...  25365.220703  25745.599609
# 859  2020-06-26          888.00  ...  25641.689453  25015.550781
# 860  2020-06-29          915.00  ...  25152.449219  25595.800781
# 861  2020-06-30          925.00  ...  25512.429688  25812.880859
#
# [862 rows x 6 columns]

# %%
#parse string to datetime
sub_dataset['Date']=pd.to_datetime(sub_dataset['Date'],infer_datetime_format=True)

# %%
#Set date as Index
sub_dataset.set_index('Date',inplace=True)

# %%
sub_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 862 entries, 2017-01-02 to 2020-06-30
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Open_BOM500002   862 non-null    float64
#  1   Close_BOM500002  862 non-null    float64
#  2   Conversion_Rate  862 non-null    float64
#  3   DJIOpen          861 non-null    float64
#  4   DJIClose         861 non-null    float64
# dtypes: float64(5)
# memory usage: 40.4 KB

# %%
sub_dataset[sub_dataset['Close_BOM500002'].isna()]
# Out:
# Empty DataFrame
# Columns: [Open_BOM500002, Close_BOM500002, Conversion_Rate, DJIOpen, DJIClose]
# Index: []

# %%
from pandas import DataFrame
from pandas import concat
 
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
	"""
	Frame a time series as a supervised learning dataset.
	Arguments:
		data: Sequence of observations as a list or NumPy array.
		n_in: Number of lag observations as input (X).
		n_out: Number of observations as output (y).
		dropnan: Boolean whether or not to drop rows with NaN values.
	Returns:
		Pandas DataFrame of series framed for supervised learning.
	"""
	n_vars = 1 if type(data) is list else data.shape[1]
	v_cols = 'Var' if type(data) is list else data.columns
	df = DataFrame(data)
	cols, names = list(), list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(df.shift(i))
		names += [(v_cols[j]+'%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(df.shift(-i))
		if i == 0:
			names += [(v_cols[j]+'%d(t)' % (j+1)) for j in range(n_vars)]
		else:
			names += [(v_cols[j]+'%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
	# put it all together
	agg = concat(cols, axis=1)
	agg.columns = names
	# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg

# %%
n_timesteps=5
n_features=len(sub_dataset.columns)
data = series_to_supervised(sub_dataset,n_timesteps,1,True)
data.head()
# Out:
#             Open_BOM5000021(t-5)  ...  DJIClose5(t)
# Date                              ...
# 2017-01-10               1069.90  ...  19855.529297
# 2017-01-11               1050.00  ...  19954.279297
# 2017-01-12               1051.90  ...  19891.000000
# 2017-01-13               1037.00  ...  19885.730469
# 2017-01-16               1047.95  ...  19856.250000
#
# [5 rows x 30 columns]

# %%
#Stock code we want to predict
target_stock='Close_BOM5000022'
columns=data.columns

#Keep on Target_stock(t) and drop other variables of (t), as we want to predict only target_stock(t)
reframed_data=data.drop([i for i in columns if '(t)' in i and i!= target_stock+'(t)'],axis=1)

# %%
reframed_data.head()
# Out:
#             Open_BOM5000021(t-5)  ...  Close_BOM5000022(t)
# Date                              ...
# 2017-01-10               1069.90  ...              1176.00
# 2017-01-11               1050.00  ...              1132.15
# 2017-01-12               1051.90  ...              1122.10
# 2017-01-13               1037.00  ...              1130.85
# 2017-01-16               1047.95  ...              1124.45
#
# [5 rows x 26 columns]

# %%
#split scaled df to train and test data
train_data, test_data = reframed_data.iloc[0:int(len(reframed_data)*0.8), :], reframed_data.iloc[int(len(reframed_data)*0.8):, :]

# %%
# scale train and test data to [0, 1]
def scale(train, test):
  # fit scaler
  scaler = MinMaxScaler(feature_range=(0, 1))
  scaler = scaler.fit(train)
  # transform train
  train = train.reshape(train.shape[0], train.shape[1])
  train_scaled = scaler.transform(train)
  # transform test
  test = test.reshape(test.shape[0], test.shape[1])
  test_scaled = scaler.transform(test)
  return scaler, train_scaled, test_scaled

# %%
# inverse scaling for a forecasted value
from numpy import concatenate
def invert_scale(scaler, X, yhat):
	array =  concatenate(( X[:, :],np.array(yhat).reshape(1,-1)), axis=1) #np.array(new_row).reshape(1,-1)
	#print(array.shape)
	inverted = scaler.inverse_transform(array)
	return inverted[:, -1]

# %%
# normalize features
scaler,train_data_scaled,test_data_scaled = scale(train_data.values,test_data.values)

# %%
#convert train scaled array to DF
train_scaled_df=pd.DataFrame(train_data_scaled,index=train_data.index,columns=train_data.columns)

# %%
#convert test scaled array to DF
test_scaled_df=pd.DataFrame(test_data_scaled,index=test_data.index,columns=test_data.columns)

# %%
train_scaled_df.head()
# Out:
#             Open_BOM5000021(t-5)  ...  Close_BOM5000022(t)
# Date                              ...
# 2017-01-10              0.050693  ...             0.134528
# 2017-01-11              0.020031  ...             0.062413
# 2017-01-12              0.022958  ...             0.045884
# 2017-01-13              0.000000  ...             0.060275
# 2017-01-16              0.016872  ...             0.049749
#
# [5 rows x 26 columns]

# %%
train_scaled_df.shape
# Out:
# (684, 26)

# %%
test_scaled_df.shape
# Out:
# (172, 26)

# %%
# split into input and outputs
train_X, train_y = train_scaled_df[:].drop(target_stock+'(t)',axis=1,inplace=False).values, train_scaled_df[target_stock+'(t)'].values
test_X, test_y = test_scaled_df[:].drop(target_stock+'(t)',axis=1,inplace=False).values, test_scaled_df[target_stock+'(t)'].values

# %%
train_X.shape,train_y.shape
# Out:
# ((684, 25), (684,))

# %%
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], n_timesteps, n_features))
test_X = test_X.reshape((test_X.shape[0], n_timesteps, n_features))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (684, 5, 5) (684,) (172, 5, 5) (172,)

# %%
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

# fit an LSTM network to training data
def fit_lstm(train_X,train_y, batch_size, nb_epoch, neurons):
  # design network
  model = Sequential()
  model.add(LSTM(neurons, return_sequences=False, batch_input_shape=(batch_size,train_X.shape[1], train_X.shape[2]),stateful=True))
  #model.add(LSTM(50, return_sequences=True))
  #model.add(LSTM(50))
  model.add(Dense(1))
  model.compile(loss=tf.keras.losses.MeanSquaredError(), optimizer='adam',metrics=['accuracy'])
  # fit network
  for i in range(nb_epoch):
    model.fit(train_X, train_y
              , epochs=1, batch_size=batch_size, verbose=2, shuffle=False
              #,callbacks=[keras.callbacks.EarlyStopping(monitor="val_loss", patience=5, mode="min") 
              )
    model.reset_states()
  #model.summary()
  return model

# %%
model=fit_lstm(train_X=train_X,train_y=train_y,batch_size=1,nb_epoch=50,neurons=50)
# Out:
# 684/684 - 1s - loss: 0.0088 - accuracy: 0.0029
# 684/684 - 1s - loss: 0.0102 - accuracy: 0.0029
# 684/684 - 1s - loss: 0.0093 - accuracy: 0.0029
# 684/684 - 1s - loss: 0.0081 - accuracy: 0.0029
# 684/684 - 2s - loss: 0.0069 - accuracy: 0.0029
# 684/684 - 2s - loss: 0.0059 - accuracy: 0.0029
# 684/684 - 1s - loss: 0.0051 - accuracy: 0.0029
# 684/684 - 1s - loss: 0.0043 - accuracy: 0.0029
# 684/684 - 1s - loss: 0.0037 - accuracy: 0.0029
# 684/684 - 1s - loss: 0.0032 - accuracy: 0.0029
# 684/684 - 1s - loss: 0.0027 - accuracy: 0.0029
# 684/684 - 1s - loss: 0.0023 - accuracy: 0.0029
# 684/684 - 1s - loss: 0.0021 - accuracy: 0.0029
# 684/684 - 1s - loss: 0.0021 - accuracy: 0.0029
# 684/684 - 1s - loss: 0.0021 - accuracy: 0.0029
# 684/684 - 1s - loss: 0.0021 - accuracy: 0.0029
# 684/684 - 1s - loss: 0.0021 - accuracy: 0.0029
# 684/684 - 1s - loss: 0.0021 - accuracy: 0.0029
# 684/684 - 1s - loss: 0.0020 - accuracy: 0.0029
# 684/684 - 1s - loss: 0.0020 - accuracy: 0.0029
# 684/684 - 1s - loss: 0.0020 - accuracy: 0.0029
# 684/684 - 1s - loss: 0.0020 - accuracy: 0.0029
# 684/684 - 1s - loss: 0.0019 - accuracy: 0.0029
# 684/684 - 1s - loss: 0.0019 - accuracy: 0.0029
# 684/684 - 1s - loss: 0.0019 - accuracy: 0.0029
# 684/684 - 1s - loss: 0.0019 - accuracy: 0.0029
# 684/684 - 1s - loss: 0.0019 - accuracy: 0.0029
# 684/684 - 1s - loss: 0.0019 - accuracy: 0.0029
# 684/684 - 1s - loss: 0.0018 - accuracy: 0.0029
# 684/684 - 1s - loss: 0.0018 - accuracy: 0.0029
# 684/684 - 1s - loss: 0.0018 - accuracy: 0.0029
# 684/684 - 1s - loss: 0.0018 - accuracy: 0.0029
# 684/684 - 1s - loss: 0.0018 - accuracy: 0.0029
# 684/684 - 1s - loss: 0.0018 - accuracy: 0.0029
# 684/684 - 1s - loss: 0.0018 - accuracy: 0.0029
# 684/684 - 1s - loss: 0.0018 - accuracy: 0.0029
# 684/684 - 1s - loss: 0.0018 - accuracy: 0.0029
# 684/684 - 1s - loss: 0.0018 - accuracy: 0.0029
# 684/684 - 1s - loss: 0.0018 - accuracy: 0.0029
# 684/684 - 1s - loss: 0.0018 - accuracy: 0.0029
# 684/684 - 1s - loss: 0.0018 - accuracy: 0.0029
# 684/684 - 1s - loss: 0.0018 - accuracy: 0.0029
# 684/684 - 1s - loss: 0.0018 - accuracy: 0.0029
# 684/684 - 1s - loss: 0.0018 - accuracy: 0.0029
# 684/684 - 1s - loss: 0.0017 - accuracy: 0.0029
# 684/684 - 1s - loss: 0.0018 - accuracy: 0.0029
# 684/684 - 1s - loss: 0.0018 - accuracy: 0.0029
# 684/684 - 1s - loss: 0.0018 - accuracy: 0.0029
# 684/684 - 1s - loss: 0.0018 - accuracy: 0.0029
# 684/684 - 1s - loss: 0.0018 - accuracy: 0.0029

# %%
# make a one-step forecast
def forecast_lstm(model, batch_size, X,timesteps):
  X = X.reshape(1, timesteps, len(X))
  yhat = model.predict(X, batch_size=batch_size)
  #print(yhat)
  return yhat[0,0]

# %%
forecast_lstm(model, 1, test_X[0],timesteps=n_timesteps)
# Out:
# [[0.7567898]]
# 0.7567898

# %%
test_X[0].shape
# Out:
# (5, 5)

# %%
test_y[0,-1]
# Out:
# 0.7332456212482528

# %%
# make a prediction for test data
predictions = list()
for i in range(test_X.shape[0]):
  # predict
  X, y = test_X[i], test_y[i,-1]
  #print(X,y)
  yhat = forecast_lstm(model, 1, X,timesteps=n_timesteps)
  X=X.reshape(1,n_timesteps* n_features)
  # invert scaling  
  #print(X.shape)
  #print(yhat)
  yhat= invert_scale(scaler, X, yhat)
  # store forecast
  predictions.append(yhat)

# %%
from math import sqrt

#print(predictions.shape)
inv_y = test_data[target_stock+'(t)'].values
print(inv_y.shape)
# calculate RMSE
rmse = sqrt(mean_squared_error(inv_y, predictions))
print('Test RMSE: %.3f' % rmse)
# Out:
# (172,)
# Test RMSE: 107.650

# %%
plt.plot(inv_y,label='Testing Data')
plt.plot(predictions,label='Predicted price for Test data')
plt.legend();

# %%
#Calculate average price of the stock based on last 5 days of test data 
avg_test_x=inv_test_data[:,(0,5,10,15,20)].mean(axis=1)

# %%
avg_test_x.shape
# Out:
# (172,)

# %%
# calculate RMSE
rmse = sqrt(mean_squared_error(inv_y, avg_test_x))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 53.648

# %%
# Update LSTM model
def update_model(model, train_X,train_y ,batch_size, updates,timesteps):
	X, y = train_X, train_y
	#X = X.reshape(X.shape[0], timesteps, X.shape[1])
	for i in range(updates):
		model.fit(X, y, epochs=1, batch_size=batch_size, verbose=2, shuffle=False)
		model.reset_states()

# %%
train_X_copy = np.copy(train_X)
train_y_copy = np.copy(train_y)
print(train_X_copy.shape)
print(train_y_copy.shape)
# make a prediction for test data
predictions = list()
for i in range(test_X.shape[0]):
  if i > 0:
    update_model(model, train_X=train_X_copy,train_y=train_y_copy, batch_size=1, updates=2,timesteps=n_timesteps)
  # predict
  X, y = test_X[i], test_y[i,-1]
  #print(X,y)
  yhat = forecast_lstm(model, 1, X,timesteps=n_timesteps)
  X=X.reshape(1,n_timesteps* n_features)
  # invert scaling  
  #print(X.shape)
  #print(yhat)
  yhat= invert_scale(scaler, X, yhat)
  # store forecast
  predictions.append(yhat)
  # add to training set
  train_X_copy = concatenate((train_X_copy, test_X[i].reshape(1,n_timesteps, n_features)))
  train_y_copy = concatenate((train_y_copy, test_y[i]))
  #.reshape(1, -1)
print(train_X_copy.shape)
print(train_y_copy.shape)
# Out:
# (684, 5, 5)
# (684,)
# 685/685 - 1s - loss: 4.9231e-04 - accuracy: 0.0029
# 685/685 - 1s - loss: 4.3592e-04 - accuracy: 0.0029
# 686/686 - 1s - loss: 5.0939e-04 - accuracy: 0.0029
# 686/686 - 1s - loss: 4.0655e-04 - accuracy: 0.0029
# 687/687 - 1s - loss: 4.3371e-04 - accuracy: 0.0029
# 687/687 - 1s - loss: 4.6627e-04 - accuracy: 0.0029
# 688/688 - 1s - loss: 4.6915e-04 - accuracy: 0.0029
# 688/688 - 1s - loss: 4.8673e-04 - accuracy: 0.0029
# 689/689 - 1s - loss: 6.6869e-04 - accuracy: 0.0029
# 689/689 - 1s - loss: 6.0721e-04 - accuracy: 0.0029
# 690/690 - 1s - loss: 4.5905e-04 - accuracy: 0.0029
# 690/690 - 1s - loss: 4.3591e-04 - accuracy: 0.0029
# 691/691 - 1s - loss: 6.0570e-04 - accuracy: 0.0029
# 691/691 - 1s - loss: 5.2332e-04 - accuracy: 0.0029
# 692/692 - 1s - loss: 4.7872e-04 - accuracy: 0.0029
# 692/692 - 1s - loss: 4.4804e-04 - accuracy: 0.0029
# 693/693 - 1s - loss: 4.0327e-04 - accuracy: 0.0029
# 693/693 - 1s - loss: 4.2646e-04 - accuracy: 0.0029
# 694/694 - 1s - loss: 5.7187e-04 - accuracy: 0.0029
# 694/694 - 1s - loss: 4.4507e-04 - accuracy: 0.0029
# 695/695 - 1s - loss: 5.5200e-04 - accuracy: 0.0029
# 695/695 - 1s - loss: 5.0025e-04 - accuracy: 0.0029
# 696/696 - 1s - loss: 5.2406e-04 - accuracy: 0.0029
# 696/696 - 1s - loss: 4.1225e-04 - accuracy: 0.0029
# 697/697 - 1s - loss: 4.4764e-04 - accuracy: 0.0029
# 697/697 - 1s - loss: 3.7947e-04 - accuracy: 0.0029
# 698/698 - 1s - loss: 7.4945e-04 - accuracy: 0.0029
# 698/698 - 1s - loss: 5.5043e-04 - accuracy: 0.0029
# 699/699 - 1s - loss: 4.9369e-04 - accuracy: 0.0029
# 699/699 - 1s - loss: 5.6646e-04 - accuracy: 0.0029
# 700/700 - 1s - loss: 4.6494e-04 - accuracy: 0.0029
# 790/790 - 2s - loss: 5.4904e-04 - accuracy: 0.0025
# 791/791 - 2s - loss: 7.1009e-04 - accuracy: 0.0025
# 791/791 - 2s - loss: 0.0010 - accuracy: 0.0025
# 792/792 - 2s - loss: 7.7955e-04 - accuracy: 0.0025
# 792/792 - 2s - loss: 7.4432e-04 - accuracy: 0.0025
# 793/793 - 2s - loss: 5.8032e-04 - accuracy: 0.0025
# 793/793 - 2s - loss: 6.2960e-04 - accuracy: 0.0025
# 794/794 - 2s - loss: 7.3026e-04 - accuracy: 0.0025
# 794/794 - 2s - loss: 9.7162e-04 - accuracy: 0.0025
# 795/795 - 2s - loss: 6.7166e-04 - accuracy: 0.0025
# 795/795 - 2s - loss: 6.1746e-04 - accuracy: 0.0025
# 796/796 - 2s - loss: 5.8103e-04 - accuracy: 0.0025
# 796/796 - 2s - loss: 5.0740e-04 - accuracy: 0.0025
# 797/797 - 2s - loss: 6.4297e-04 - accuracy: 0.0025
# 797/797 - 2s - loss: 5.9497e-04 - accuracy: 0.0025
# 798/798 - 2s - loss: 6.3278e-04 - accuracy: 0.0025
# 798/798 - 2s - loss: 6.7200e-04 - accuracy: 0.0025
# 799/799 - 2s - loss: 6.1056e-04 - accuracy: 0.0025
# 799/799 - 2s - loss: 5.9404e-04 - accuracy: 0.0025
# 800/800 - 2s - loss: 5.8256e-04 - accuracy: 0.0025
# 800/800 - 2s - loss: 5.1478e-04 - accuracy: 0.0025
# 801/801 - 2s - loss: 4.7930e-04 - accuracy: 0.0025
# 801/801 - 2s - loss: 5.2295e-04 - accuracy: 0.0025
# 802/802 - 2s - loss: 5.4533e-04 - accuracy: 0.0025
# 802/802 - 2s - loss: 6.0246e-04 - accuracy: 0.0025
# 803/803 - 2s - loss: 6.3676e-04 - accuracy: 0.0025
# 803/803 - 2s - loss: 7.7436e-04 - accuracy: 0.0025
# 804/804 - 2s - loss: 5.2428e-04 - accuracy: 0.0025
# 804/804 - 2s - loss: 5.5816e-04 - accuracy: 0.0025
# 805/805 - 2s - loss: 4.7963e-04 - accuracy: 0.0025
# 805/805 - 2s - loss: 4.1660e-04 - accuracy: 0.0025
# 806/806 - 2s - loss: 6.6416e-04 - accuracy: 0.0025
# 806/806 - 2s - loss: 5.3808e-04 - accuracy: 0.0025
# 807/807 - 2s - loss: 6.2411e-04 - accuracy: 0.0025
# 807/807 - 2s - loss: 4.7843e-04 - accuracy: 0.0025
# 808/808 - 2s - loss: 4.7428e-04 - accuracy: 0.0025
# 808/808 - 2s - loss: 4.2292e-04 - accuracy: 0.0025
# 809/809 - 2s - loss: 3.9810e-04 - accuracy: 0.0025
# 809/809 - 2s - loss: 4.8016e-04 - accuracy: 0.0025
# 810/810 - 2s - loss: 4.0603e-04 - accuracy: 0.0025
# 810/810 - 2s - loss: 3.9797e-04 - accuracy: 0.0025
# 811/811 - 2s - loss: 4.8339e-04 - accuracy: 0.0025
# 811/811 - 2s - loss: 5.4948e-04 - accuracy: 0.0025
# 812/812 - 2s - loss: 5.2548e-04 - accuracy: 0.0025
# 812/812 - 2s - loss: 5.7756e-04 - accuracy: 0.0025
# 813/813 - 2s - loss: 7.0091e-04 - accuracy: 0.0025
# 813/813 - 2s - loss: 6.7961e-04 - accuracy: 0.0025
# 814/814 - 2s - loss: 6.4261e-04 - accuracy: 0.0025
# 814/814 - 2s - loss: 4.8063e-04 - accuracy: 0.0025
# 815/815 - 2s - loss: 3.5736e-04 - accuracy: 0.0025
# 815/815 - 2s - loss: 5.9300e-04 - accuracy: 0.0025
# 816/816 - 2s - loss: 6.6145e-04 - accuracy: 0.0025
# 816/816 - 2s - loss: 6.1861e-04 - accuracy: 0.0025
# 817/817 - 2s - loss: 5.4368e-04 - accuracy: 0.0024
# 817/817 - 2s - loss: 6.1466e-04 - accuracy: 0.0024
# 818/818 - 2s - loss: 6.1529e-04 - accuracy: 0.0024
# 818/818 - 2s - loss: 5.0075e-04 - accuracy: 0.0024
# 819/819 - 2s - loss: 4.9346e-04 - accuracy: 0.0024
# 819/819 - 2s - loss: 6.1081e-04 - accuracy: 0.0024
# 820/820 - 2s - loss: 4.2129e-04 - accuracy: 0.0024
# 820/820 - 2s - loss: 5.1459e-04 - accuracy: 0.0024
# 821/821 - 2s - loss: 5.9360e-04 - accuracy: 0.0024
# 821/821 - 2s - loss: 5.8421e-04 - accuracy: 0.0024
# 822/822 - 2s - loss: 8.2368e-04 - accuracy: 0.0024
# 822/822 - 2s - loss: 7.3768e-04 - accuracy: 0.0024
# 823/823 - 2s - loss: 5.6272e-04 - accuracy: 0.0024
# 823/823 - 2s - loss: 6.0744e-04 - accuracy: 0.0024
# 824/824 - 2s - loss: 4.8252e-04 - accuracy: 0.0024
# 824/824 - 2s - loss: 4.7922e-04 - accuracy: 0.0024
# 825/825 - 2s - loss: 5.1710e-04 - accuracy: 0.0024
# 825/825 - 2s - loss: 6.6640e-04 - accuracy: 0.0024
# 826/826 - 2s - loss: 7.4869e-04 - accuracy: 0.0024
# 826/826 - 2s - loss: 4.5843e-04 - accuracy: 0.0024
# 827/827 - 2s - loss: 5.6563e-04 - accuracy: 0.0024
# 827/827 - 2s - loss: 5.6490e-04 - accuracy: 0.0024
# 828/828 - 2s - loss: 5.0504e-04 - accuracy: 0.0024
# 828/828 - 2s - loss: 5.1511e-04 - accuracy: 0.0024
# 829/829 - 2s - loss: 8.0150e-04 - accuracy: 0.0024
# 829/829 - 2s - loss: 7.5002e-04 - accuracy: 0.0024
# 830/830 - 2s - loss: 8.1245e-04 - accuracy: 0.0024
# 830/830 - 2s - loss: 7.2291e-04 - accuracy: 0.0024
# 831/831 - 2s - loss: 4.8238e-04 - accuracy: 0.0024
# 831/831 - 2s - loss: 4.3015e-04 - accuracy: 0.0024
# 832/832 - 2s - loss: 4.2026e-04 - accuracy: 0.0024
# 832/832 - 2s - loss: 4.5974e-04 - accuracy: 0.0024
# 833/833 - 2s - loss: 3.9652e-04 - accuracy: 0.0024
# 833/833 - 2s - loss: 6.4774e-04 - accuracy: 0.0024
# 834/834 - 2s - loss: 6.5774e-04 - accuracy: 0.0024
# 834/834 - 2s - loss: 4.9635e-04 - accuracy: 0.0024
# 835/835 - 2s - loss: 6.0797e-04 - accuracy: 0.0024
# 835/835 - 2s - loss: 4.9901e-04 - accuracy: 0.0024
# 836/836 - 2s - loss: 5.0243e-04 - accuracy: 0.0024
# 836/836 - 2s - loss: 5.9942e-04 - accuracy: 0.0024
# 837/837 - 2s - loss: 7.8804e-04 - accuracy: 0.0024
# 837/837 - 2s - loss: 6.5032e-04 - accuracy: 0.0024
# 838/838 - 2s - loss: 8.0008e-04 - accuracy: 0.0024
# 838/838 - 2s - loss: 5.4385e-04 - accuracy: 0.0024
# 839/839 - 2s - loss: 4.9441e-04 - accuracy: 0.0024
# 839/839 - 2s - loss: 5.6754e-04 - accuracy: 0.0024
# 840/840 - 2s - loss: 6.0430e-04 - accuracy: 0.0024
# 840/840 - 2s - loss: 7.0073e-04 - accuracy: 0.0024
# 841/841 - 2s - loss: 7.5636e-04 - accuracy: 0.0024
# 841/841 - 2s - loss: 5.7065e-04 - accuracy: 0.0024
# 842/842 - 2s - loss: 5.5564e-04 - accuracy: 0.0024
# 842/842 - 2s - loss: 4.9872e-04 - accuracy: 0.0024
# 843/843 - 2s - loss: 5.0338e-04 - accuracy: 0.0024
# 843/843 - 2s - loss: 5.6644e-04 - accuracy: 0.0024
# 844/844 - 2s - loss: 5.8500e-04 - accuracy: 0.0024
# 844/844 - 2s - loss: 5.0033e-04 - accuracy: 0.0024
# 845/845 - 2s - loss: 5.4936e-04 - accuracy: 0.0024
# 845/845 - 2s - loss: 7.5067e-04 - accuracy: 0.0024
# 846/846 - 2s - loss: 6.9069e-04 - accuracy: 0.0024
# 846/846 - 2s - loss: 6.0768e-04 - accuracy: 0.0024
# 847/847 - 2s - loss: 5.6150e-04 - accuracy: 0.0024
# 847/847 - 2s - loss: 5.6339e-04 - accuracy: 0.0024
# 848/848 - 2s - loss: 5.1985e-04 - accuracy: 0.0024
# 848/848 - 2s - loss: 5.9053e-04 - accuracy: 0.0024
# 849/849 - 2s - loss: 4.4720e-04 - accuracy: 0.0024
# 849/849 - 2s - loss: 7.4434e-04 - accuracy: 0.0024
# 850/850 - 2s - loss: 6.0398e-04 - accuracy: 0.0024
# 850/850 - 2s - loss: 5.0062e-04 - accuracy: 0.0024
# 851/851 - 2s - loss: 4.6500e-04 - accuracy: 0.0024
# 851/851 - 2s - loss: 5.5392e-04 - accuracy: 0.0024
# 852/852 - 2s - loss: 5.1640e-04 - accuracy: 0.0023
# 852/852 - 2s - loss: 5.0966e-04 - accuracy: 0.0023
# 853/853 - 2s - loss: 5.2509e-04 - accuracy: 0.0023
# 853/853 - 2s - loss: 5.0820e-04 - accuracy: 0.0023
# 854/854 - 2s - loss: 4.7814e-04 - accuracy: 0.0023
# 854/854 - 2s - loss: 6.0586e-04 - accuracy: 0.0023
# 855/855 - 2s - loss: 5.0740e-04 - accuracy: 0.0023
# 855/855 - 2s - loss: 8.0890e-04 - accuracy: 0.0023
# (856, 5, 5)
# (856,)

# %%
from math import sqrt

#print(predictions.shape)
inv_y = test_data[target_stock+'(t)'].values
print(inv_y.shape)
# calculate RMSE
rmse = sqrt(mean_squared_error(inv_y, predictions))
print('Test RMSE: %.3f' % rmse)
# Out:
# (172,)
# Test RMSE: 66.913

# %%
plt.plot(inv_y,label='Testing Data', color='blue')
plt.plot(predictions,label='Predicted price for Test data',color='red')
plt.plot(avg_test_x,label='Avg Price for Test data',color='green')
plt.legend();
